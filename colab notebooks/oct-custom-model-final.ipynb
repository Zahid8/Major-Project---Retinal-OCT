# %%
import tensorflow as tf
from tensorflow import keras
import tensorflow_datasets as tfds

tfds.disable_progress_bar()

import os
import sys
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !pip install --upgrade -q kaggle

# !mkdir /root/.kaggle
import json
token = {
    "username": "zahidhussain909",
    "key": "39a06efd89d0f2a699143b8d3d62b216"
}

with open('/root/.kaggle/kaggle.json', 'w') as config_file:
    json.dump(token, config_file)
# !chmod 600 /root/.kaggle/kaggle.json

# !kaggle datasets download -d zahidhussain909/denoised-oct-balanced
# Out:
# Downloading denoised-oct-balanced.zip to /content
#  99% 1.04G/1.05G [00:09<00:00, 165MB/s]
# 100% 1.05G/1.05G [00:09<00:00, 113MB/s]

# %%
import zipfile
zipref=zipfile.ZipFile("/content/denoised-oct-balanced.zip",'r')
zipref.extractall()
zipref.close()

# !rm -rf /content/denoised-oct-balanced.zip

# %%
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
num_class=len(os.listdir("/content/DENOISED OCT/train"))
num_class

train_dir = "/content/DENOISED OCT/train"
test_dir = "/content/DENOISED OCT/train"


train_datagen=ImageDataGenerator(rescale=1/255.)
test_datagen=ImageDataGenerator(rescale=1/255.)

train_set = train_datagen.flow_from_directory(train_dir,batch_size=32,
                                               class_mode='categorical',
                                               target_size=(180,180))

val_set = test_datagen.flow_from_directory(test_dir,batch_size=32,
                                               class_mode='categorical',
                                               target_size=(180,180))
# Out:
# Found 32060 images belonging to 4 classes.
# Found 32060 images belonging to 4 classes.

# %%
num_classes = 4
input_shape = (180,180,3)

# %%
# Model
#IMAGE_SIZE = [224, 224]
IMAGE_SIZE=180
BATCH_SIZE = 32  # on Colab/GPU, a higher batch size may throw(OOM)

# Dataset
CLASSES = [
    "CNV",
    "DME",
    "DRUSEN",
    "NORMAL"
]  # don't change the order

# Other constants
MEAN = tf.constant([0.485 * 255, 0.456 * 255, 0.406 * 255])  # imagenet mean
STD = tf.constant([0.229 * 255, 0.224 * 255, 0.225 * 255])  # imagenet std
AUTO = tf.data.AUTOTUNE

# %%
sample_images, sample_labels = next(iter(train_set))

plt.figure(figsize=(5 * 3, 3 * 3))
for n in range(15):
    ax = plt.subplot(3, 5, n + 1)
    image = (sample_images[n])
    image = (image - image.min()) / (
        image.max() - image.min()
    )  # convert to [0, 1] for avoiding matplotlib warning
    plt.imshow(image)
    #plt.title(CLASSES[sample_labels[n]])
    plt.axis("off")
plt.tight_layout()
plt.show()

# %%
custom5 = tf.keras.Sequential([
                              tf.keras.layers.Conv2D(100,3,activation='relu',input_shape=(180,180,3)),
                              tf.keras.layers.BatchNormalization(),
                              tf.keras.layers.MaxPool2D(pool_size=3,padding='valid'),
                              tf.keras.layers.Conv2D(70,3,activation='relu'),
                              tf.keras.layers.BatchNormalization(),
                              tf.keras.layers.MaxPool2D(),
                              tf.keras.layers.Conv2D(50,3,activation='relu'),
                              tf.keras.layers.BatchNormalization(),
                              tf.keras.layers.MaxPool2D(),
                              tf.keras.layers.Conv2D(20,3,activation='relu'),
                              tf.keras.layers.BatchNormalization(),
                              tf.keras.layers.MaxPool2D(),
                              tf.keras.layers.Dropout(0.5),
                              tf.keras.layers.Flatten(),
                              tf.keras.layers.Dense(4,activation='softmax')       
])

# %%
custom5.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 178, 178, 100)     2800
#
#  batch_normalization (BatchN  (None, 178, 178, 100)    400
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 59, 59, 100)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 57, 57, 70)        63070
#
#  batch_normalization_1 (Batc  (None, 57, 57, 70)       280
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 28, 28, 70)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 26, 26, 50)        31550
#
#  batch_normalization_2 (Batc  (None, 26, 26, 50)       200
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 13, 13, 50)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 11, 11, 20)        9020
#
#  batch_normalization_3 (Batc  (None, 11, 11, 20)       80
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 5, 5, 20)         0
#  2D)
#
#  dropout (Dropout)           (None, 5, 5, 20)          0
#
#  flatten (Flatten)           (None, 500)               0
#
#  dense (Dense)               (None, 4)                 2004
#
# =================================================================
# Total params: 109,404
# Trainable params: 108,924
# Non-trainable params: 480
# _________________________________________________________________

# %%
custom5.compile(loss='categorical_crossentropy',
               optimizer=tf.keras.optimizers.Adam(),
               metrics=[tf.keras.metrics.AUC(),tf.keras.metrics.Precision(),tf.keras.metrics.Recall(),tf.keras.metrics.PrecisionAtRecall(0.5),tf.keras.metrics.TrueNegatives(),tf.keras.metrics.FalsePositives(),tf.keras.metrics.SpecificityAtSensitivity(0.5),'accuracy'])

history_5=custom5.fit(train_set,epochs=50,steps_per_epoch=len(train_set),validation_data=val_set,validation_steps=len(val_set),
                    callbacks = [tf.keras.callbacks.ModelCheckpoint("classify_model4.h5", monitor='accuracy', save_best_only=True, verbose = 1)])
# Out:
# Epoch 1/50
# 1002/1002 [==============================] - ETA: 0s - loss: 1.0684 - auc: 0.8232 - precision: 0.6331 - recall: 0.5086 - precision_at_recall: 0.6362 - true_negatives: 86728.0000 - false_positives: 9452.0000 - specificity_at_sensitivity: 0.9042 - accuracy: 0.5834
# Epoch 1: accuracy improved from -inf to 0.58341, saving model to classify_model4.h5
# 1002/1002 [==============================] - 157s 143ms/step - loss: 1.0684 - auc: 0.8232 - precision: 0.6331 - recall: 0.5086 - precision_at_recall: 0.6362 - true_negatives: 86728.0000 - false_positives: 9452.0000 - specificity_at_sensitivity: 0.9042 - accuracy: 0.5834 - val_loss: 0.6034 - val_auc: 0.9363 - val_precision: 0.8027 - val_recall: 0.7126 - val_precision_at_recall: 0.8890 - val_true_negatives: 90566.0000 - val_false_positives: 5614.0000 - val_specificity_at_sensitivity: 0.9790 - val_accuracy: 0.7630
# Epoch 2/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.5172 - auc: 0.9530 - precision: 0.8319 - recall: 0.7765 - precision_at_recall: 0.9334 - true_negatives: 91148.0000 - false_positives: 5032.0000 - specificity_at_sensitivity: 0.9881 - accuracy: 0.8053
# Epoch 2: accuracy improved from 0.58341 to 0.80527, saving model to classify_model4.h5
# 1002/1002 [==============================] - 140s 140ms/step - loss: 0.5172 - auc: 0.9530 - precision: 0.8319 - recall: 0.7765 - precision_at_recall: 0.9334 - true_negatives: 91148.0000 - false_positives: 5032.0000 - specificity_at_sensitivity: 0.9881 - accuracy: 0.8053 - val_loss: 0.4713 - val_auc: 0.9604 - val_precision: 0.8482 - val_recall: 0.7999 - val_precision_at_recall: 0.9476 - val_true_negatives: 91591.0000 - val_false_positives: 4589.0000 - val_specificity_at_sensitivity: 0.9908 - val_accuracy: 0.8249
# Epoch 3/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.4128 - auc: 0.9691 - precision: 0.8649 - recall: 0.8292 - precision_at_recall: 0.9611 - true_negatives: 92028.0000 - false_positives: 4152.0000 - specificity_at_sensitivity: 0.9931 - accuracy: 0.8475
# Epoch 3: accuracy improved from 0.80527 to 0.84754, saving model to classify_model4.h5
# 1002/1002 [==============================] - 143s 143ms/step - loss: 0.4128 - auc: 0.9691 - precision: 0.8649 - recall: 0.8292 - precision_at_recall: 0.9611 - true_negatives: 92028.0000 - false_positives: 4152.0000 - specificity_at_sensitivity: 0.9931 - accuracy: 0.8475 - val_loss: 0.6998 - val_auc: 0.9254 - val_precision: 0.7397 - val_recall: 0.7017 - val_precision_at_recall: 0.8577 - val_true_negatives: 88265.0000 - val_false_positives: 7915.0000 - val_specificity_at_sensitivity: 0.9722 - val_accuracy: 0.7217
# Epoch 4/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.3617 - auc: 0.9755 - precision: 0.8839 - recall: 0.8570 - precision_at_recall: 0.9709 - true_negatives: 92571.0000 - false_positives: 3609.0000 - specificity_at_sensitivity: 0.9950 - accuracy: 0.8716
# Epoch 4: accuracy improved from 0.84754 to 0.87165, saving model to classify_model4.h5
# 1002/1002 [==============================] - 139s 139ms/step - loss: 0.3617 - auc: 0.9755 - precision: 0.8839 - recall: 0.8570 - precision_at_recall: 0.9709 - true_negatives: 92571.0000 - false_positives: 3609.0000 - specificity_at_sensitivity: 0.9950 - accuracy: 0.8716 - val_loss: 0.7491 - val_auc: 0.9315 - val_precision: 0.7592 - val_recall: 0.7251 - val_precision_at_recall: 0.9349 - val_true_negatives: 88805.0000 - val_false_positives: 7375.0000 - val_specificity_at_sensitivity: 0.9882 - val_accuracy: 0.7414
# Epoch 5/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.3272 - auc: 0.9798 - precision: 0.8945 - recall: 0.8730 - precision_at_recall: 0.9791 - true_negatives: 92880.0000 - false_positives: 3300.0000 - specificity_at_sensitivity: 0.9964 - accuracy: 0.8847
# Epoch 5: accuracy improved from 0.87165 to 0.88465, saving model to classify_model4.h5
# 1002/1002 [==============================] - 139s 139ms/step - loss: 0.3272 - auc: 0.9798 - precision: 0.8945 - recall: 0.8730 - precision_at_recall: 0.9791 - true_negatives: 92880.0000 - false_positives: 3300.0000 - specificity_at_sensitivity: 0.9964 - accuracy: 0.8847 - val_loss: 0.3072 - val_auc: 0.9821 - val_precision: 0.8959 - val_recall: 0.8753 - val_precision_at_recall: 0.9823 - val_true_negatives: 92918.0000 - val_false_positives: 3262.0000 - val_specificity_at_sensitivity: 0.9970 - val_accuracy: 0.8856
# Epoch 6/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.3030 - auc: 0.9822 - precision: 0.9037 - recall: 0.8850 - precision_at_recall: 0.9817 - true_negatives: 93157.0000 - false_positives: 3023.0000 - specificity_at_sensitivity: 0.9968 - accuracy: 0.8941
# Epoch 6: accuracy improved from 0.88465 to 0.89410, saving model to classify_model4.h5
# 1002/1002 [==============================] - 139s 139ms/step - loss: 0.3030 - auc: 0.9822 - precision: 0.9037 - recall: 0.8850 - precision_at_recall: 0.9817 - true_negatives: 93157.0000 - false_positives: 3023.0000 - specificity_at_sensitivity: 0.9968 - accuracy: 0.8941 - val_loss: 0.3886 - val_auc: 0.9741 - val_precision: 0.8672 - val_recall: 0.8463 - val_precision_at_recall: 0.9792 - val_true_negatives: 92026.0000 - val_false_positives: 4154.0000 - val_specificity_at_sensitivity: 0.9964 - val_accuracy: 0.8561
# Epoch 7/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.2861 - auc: 0.9841 - precision: 0.9064 - recall: 0.8882 - precision_at_recall: 0.9858 - true_negatives: 93238.0000 - false_positives: 2942.0000 - specificity_at_sensitivity: 0.9976 - accuracy: 0.8974
# Epoch 7: accuracy improved from 0.89410 to 0.89741, saving model to classify_model4.h5
# 1002/1002 [==============================] - 139s 139ms/step - loss: 0.2861 - auc: 0.9841 - precision: 0.9064 - recall: 0.8882 - precision_at_recall: 0.9858 - true_negatives: 93238.0000 - false_positives: 2942.0000 - specificity_at_sensitivity: 0.9976 - accuracy: 0.8974 - val_loss: 0.3523 - val_auc: 0.9772 - val_precision: 0.8789 - val_recall: 0.8604 - val_precision_at_recall: 0.9767 - val_true_negatives: 92381.0000 - val_false_positives: 3799.0000 - val_specificity_at_sensitivity: 0.9960 - val_accuracy: 0.8692
# Epoch 8/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.2726 - auc: 0.9853 - precision: 0.9126 - recall: 0.8956 - precision_at_recall: 0.9874 - true_negatives: 93431.0000 - false_positives: 2749.0000 - specificity_at_sensitivity: 0.9979 - accuracy: 0.9047
# Epoch 8: accuracy improved from 0.89741 to 0.90468, saving model to classify_model4.h5
# 1002/1002 [==============================] - 139s 138ms/step - loss: 0.2726 - auc: 0.9853 - precision: 0.9126 - recall: 0.8956 - precision_at_recall: 0.9874 - true_negatives: 93431.0000 - false_positives: 2749.0000 - specificity_at_sensitivity: 0.9979 - accuracy: 0.9047 - val_loss: 0.2870 - val_auc: 0.9844 - val_precision: 0.9071 - val_recall: 0.8855 - val_precision_at_recall: 0.9871 - val_true_negatives: 93273.0000 - val_false_positives: 2907.0000 - val_specificity_at_sensitivity: 0.9978 - val_accuracy: 0.8957
# Epoch 9/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.2544 - auc: 0.9870 - precision: 0.9186 - recall: 0.9045 - precision_at_recall: 0.9887 - true_negatives: 93609.0000 - false_positives: 2571.0000 - specificity_at_sensitivity: 0.9981 - accuracy: 0.9117
# Epoch 9: accuracy improved from 0.90468 to 0.91173, saving model to classify_model4.h5
# 1002/1002 [==============================] - 138s 137ms/step - loss: 0.2544 - auc: 0.9870 - precision: 0.9186 - recall: 0.9045 - precision_at_recall: 0.9887 - true_negatives: 93609.0000 - false_positives: 2571.0000 - specificity_at_sensitivity: 0.9981 - accuracy: 0.9117 - val_loss: 0.3975 - val_auc: 0.9720 - val_precision: 0.8696 - val_recall: 0.8469 - val_precision_at_recall: 0.9758 - val_true_negatives: 92108.0000 - val_false_positives: 4072.0000 - val_specificity_at_sensitivity: 0.9957 - val_accuracy: 0.8573
# Epoch 10/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.2419 - auc: 0.9882 - precision: 0.9231 - recall: 0.9097 - precision_at_recall: 0.9900 - true_negatives: 93752.0000 - false_positives: 2428.0000 - specificity_at_sensitivity: 0.9982 - accuracy: 0.9157
# Epoch 10: accuracy improved from 0.91173 to 0.91569, saving model to classify_model4.h5
# 1002/1002 [==============================] - 138s 138ms/step - loss: 0.2419 - auc: 0.9882 - precision: 0.9231 - recall: 0.9097 - precision_at_recall: 0.9900 - true_negatives: 93752.0000 - false_positives: 2428.0000 - specificity_at_sensitivity: 0.9982 - accuracy: 0.9157 - val_loss: 0.2346 - val_auc: 0.9891 - val_precision: 0.9193 - val_recall: 0.9084 - val_precision_at_recall: 0.9920 - val_true_negatives: 93625.0000 - val_false_positives: 2555.0000 - val_specificity_at_sensitivity: 0.9986 - val_accuracy: 0.9141
# Epoch 11/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.2294 - auc: 0.9892 - precision: 0.9282 - recall: 0.9155 - precision_at_recall: 0.9915 - true_negatives: 93909.0000 - false_positives: 2271.0000 - specificity_at_sensitivity: 0.9985 - accuracy: 0.9221
# Epoch 11: accuracy improved from 0.91569 to 0.92215, saving model to classify_model4.h5
# 1002/1002 [==============================] - 138s 138ms/step - loss: 0.2294 - auc: 0.9892 - precision: 0.9282 - recall: 0.9155 - precision_at_recall: 0.9915 - true_negatives: 93909.0000 - false_positives: 2271.0000 - specificity_at_sensitivity: 0.9985 - accuracy: 0.9221 - val_loss: 0.1913 - val_auc: 0.9929 - val_precision: 0.9416 - val_recall: 0.9271 - val_precision_at_recall: 0.9958 - val_true_negatives: 94336.0000 - val_false_positives: 1844.0000 - val_specificity_at_sensitivity: 0.9993 - val_accuracy: 0.9347
# Epoch 12/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.2222 - auc: 0.9899 - precision: 0.9283 - recall: 0.9172 - precision_at_recall: 0.9924 - true_negatives: 93909.0000 - false_positives: 2271.0000 - specificity_at_sensitivity: 0.9987 - accuracy: 0.9227
# Epoch 12: accuracy improved from 0.92215 to 0.92271, saving model to classify_model4.h5
# 1002/1002 [==============================] - 138s 138ms/step - loss: 0.2222 - auc: 0.9899 - precision: 0.9283 - recall: 0.9172 - precision_at_recall: 0.9924 - true_negatives: 93909.0000 - false_positives: 2271.0000 - specificity_at_sensitivity: 0.9987 - accuracy: 0.9227 - val_loss: 0.3052 - val_auc: 0.9820 - val_precision: 0.8929 - val_recall: 0.8764 - val_precision_at_recall: 0.9817 - val_true_negatives: 92808.0000 - val_false_positives: 3372.0000 - val_specificity_at_sensitivity: 0.9968 - val_accuracy: 0.8845
# Epoch 13/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.2093 - auc: 0.9910 - precision: 0.9317 - recall: 0.9211 - precision_at_recall: 0.9947 - true_negatives: 94014.0000 - false_positives: 2166.0000 - specificity_at_sensitivity: 0.9991 - accuracy: 0.9259
# Epoch 13: accuracy improved from 0.92271 to 0.92592, saving model to classify_model4.h5
# 1002/1002 [==============================] - 139s 138ms/step - loss: 0.2093 - auc: 0.9910 - precision: 0.9317 - recall: 0.9211 - precision_at_recall: 0.9947 - true_negatives: 94014.0000 - false_positives: 2166.0000 - specificity_at_sensitivity: 0.9991 - accuracy: 0.9259 - val_loss: 0.5670 - val_auc: 0.9514 - val_precision: 0.8167 - val_recall: 0.7951 - val_precision_at_recall: 0.9260 - val_true_negatives: 90458.0000 - val_false_positives: 5722.0000 - val_specificity_at_sensitivity: 0.9865 - val_accuracy: 0.8059
# Epoch 14/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.2043 - auc: 0.9913 - precision: 0.9326 - recall: 0.9224 - precision_at_recall: 0.9952 - true_negatives: 94043.0000 - false_positives: 2137.0000 - specificity_at_sensitivity: 0.9992 - accuracy: 0.9275
# Epoch 14: accuracy improved from 0.92592 to 0.92751, saving model to classify_model4.h5
# 1002/1002 [==============================] - 137s 137ms/step - loss: 0.2043 - auc: 0.9913 - precision: 0.9326 - recall: 0.9224 - precision_at_recall: 0.9952 - true_negatives: 94043.0000 - false_positives: 2137.0000 - specificity_at_sensitivity: 0.9992 - accuracy: 0.9275 - val_loss: 0.2253 - val_auc: 0.9901 - val_precision: 0.9284 - val_recall: 0.9121 - val_precision_at_recall: 0.9968 - val_true_negatives: 93924.0000 - val_false_positives: 2256.0000 - val_specificity_at_sensitivity: 0.9994 - val_accuracy: 0.9194
# Epoch 15/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.1909 - auc: 0.9921 - precision: 0.9398 - recall: 0.9304 - precision_at_recall: 0.9942 - true_negatives: 94268.0000 - false_positives: 1912.0000 - specificity_at_sensitivity: 0.9989 - accuracy: 0.9350
# Epoch 15: accuracy improved from 0.92751 to 0.93500, saving model to classify_model4.h5
# 1002/1002 [==============================] - 138s 137ms/step - loss: 0.1909 - auc: 0.9921 - precision: 0.9398 - recall: 0.9304 - precision_at_recall: 0.9942 - true_negatives: 94268.0000 - false_positives: 1912.0000 - specificity_at_sensitivity: 0.9989 - accuracy: 0.9350 - val_loss: 0.1454 - val_auc: 0.9961 - val_precision: 0.9569 - val_recall: 0.9465 - val_precision_at_recall: 0.9983 - val_true_negatives: 94814.0000 - val_false_positives: 1366.0000 - val_specificity_at_sensitivity: 0.9997 - val_accuracy: 0.9512
# Epoch 16/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.1829 - auc: 0.9928 - precision: 0.9393 - recall: 0.9314 - precision_at_recall: 0.9962 - true_negatives: 94249.0000 - false_positives: 1931.0000 - specificity_at_sensitivity: 0.9994 - accuracy: 0.9352
# Epoch 16: accuracy improved from 0.93500 to 0.93522, saving model to classify_model4.h5
# 1002/1002 [==============================] - 137s 137ms/step - loss: 0.1829 - auc: 0.9928 - precision: 0.9393 - recall: 0.9314 - precision_at_recall: 0.9962 - true_negatives: 94249.0000 - false_positives: 1931.0000 - specificity_at_sensitivity: 0.9994 - accuracy: 0.9352 - val_loss: 0.3367 - val_auc: 0.9819 - val_precision: 0.8859 - val_recall: 0.8792 - val_precision_at_recall: 0.9872 - val_true_negatives: 92551.0000 - val_false_positives: 3629.0000 - val_specificity_at_sensitivity: 0.9975 - val_accuracy: 0.8823
# Epoch 17/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.1762 - auc: 0.9933 - precision: 0.9420 - recall: 0.9348 - precision_at_recall: 0.9964 - true_negatives: 94335.0000 - false_positives: 1845.0000 - specificity_at_sensitivity: 0.9994 - accuracy: 0.9382
# Epoch 17: accuracy improved from 0.93522 to 0.93821, saving model to classify_model4.h5
# 1002/1002 [==============================] - 138s 138ms/step - loss: 0.1762 - auc: 0.9933 - precision: 0.9420 - recall: 0.9348 - precision_at_recall: 0.9964 - true_negatives: 94335.0000 - false_positives: 1845.0000 - specificity_at_sensitivity: 0.9994 - accuracy: 0.9382 - val_loss: 0.2165 - val_auc: 0.9913 - val_precision: 0.9330 - val_recall: 0.9103 - val_precision_at_recall: 0.9989 - val_true_negatives: 94083.0000 - val_false_positives: 2097.0000 - val_specificity_at_sensitivity: 0.9998 - val_accuracy: 0.9206
# Epoch 18/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.1722 - auc: 0.9936 - precision: 0.9437 - recall: 0.9351 - precision_at_recall: 0.9965 - true_negatives: 94391.0000 - false_positives: 1789.0000 - specificity_at_sensitivity: 0.9994 - accuracy: 0.9394
# Epoch 18: accuracy improved from 0.93821 to 0.93943, saving model to classify_model4.h5
# 1002/1002 [==============================] - 139s 139ms/step - loss: 0.1722 - auc: 0.9936 - precision: 0.9437 - recall: 0.9351 - precision_at_recall: 0.9965 - true_negatives: 94391.0000 - false_positives: 1789.0000 - specificity_at_sensitivity: 0.9994 - accuracy: 0.9394 - val_loss: 0.1404 - val_auc: 0.9957 - val_precision: 0.9548 - val_recall: 0.9490 - val_precision_at_recall: 0.9976 - val_true_negatives: 94740.0000 - val_false_positives: 1440.0000 - val_specificity_at_sensitivity: 0.9996 - val_accuracy: 0.9524
# Epoch 19/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.1628 - auc: 0.9940 - precision: 0.9470 - recall: 0.9405 - precision_at_recall: 0.9957 - true_negatives: 94494.0000 - false_positives: 1686.0000 - specificity_at_sensitivity: 0.9992 - accuracy: 0.9438
# Epoch 19: accuracy improved from 0.93943 to 0.94382, saving model to classify_model4.h5
# 1002/1002 [==============================] - 138s 138ms/step - loss: 0.1628 - auc: 0.9940 - precision: 0.9470 - recall: 0.9405 - precision_at_recall: 0.9957 - true_negatives: 94494.0000 - false_positives: 1686.0000 - specificity_at_sensitivity: 0.9992 - accuracy: 0.9438 - val_loss: 0.1116 - val_auc: 0.9977 - val_precision: 0.9673 - val_recall: 0.9609 - val_precision_at_recall: 0.9994 - val_true_negatives: 95138.0000 - val_false_positives: 1042.0000 - val_specificity_at_sensitivity: 0.9999 - val_accuracy: 0.9639
# Epoch 20/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.1561 - auc: 0.9945 - precision: 0.9501 - recall: 0.9437 - precision_at_recall: 0.9964 - true_negatives: 94592.0000 - false_positives: 1588.0000 - specificity_at_sensitivity: 0.9993 - accuracy: 0.9467
# Epoch 20: accuracy improved from 0.94382 to 0.94672, saving model to classify_model4.h5
# 1002/1002 [==============================] - 139s 139ms/step - loss: 0.1561 - auc: 0.9945 - precision: 0.9501 - recall: 0.9437 - precision_at_recall: 0.9964 - true_negatives: 94592.0000 - false_positives: 1588.0000 - specificity_at_sensitivity: 0.9993 - accuracy: 0.9467 - val_loss: 0.1766 - val_auc: 0.9932 - val_precision: 0.9429 - val_recall: 0.9331 - val_precision_at_recall: 0.9973 - val_true_negatives: 94367.0000 - val_false_positives: 1813.0000 - val_specificity_at_sensitivity: 0.9995 - val_accuracy: 0.9380
# Epoch 21/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.1529 - auc: 0.9947 - precision: 0.9506 - recall: 0.9449 - precision_at_recall: 0.9966 - true_negatives: 94607.0000 - false_positives: 1573.0000 - specificity_at_sensitivity: 0.9994 - accuracy: 0.9476
# Epoch 21: accuracy improved from 0.94672 to 0.94763, saving model to classify_model4.h5
# 1002/1002 [==============================] - 138s 137ms/step - loss: 0.1529 - auc: 0.9947 - precision: 0.9506 - recall: 0.9449 - precision_at_recall: 0.9966 - true_negatives: 94607.0000 - false_positives: 1573.0000 - specificity_at_sensitivity: 0.9994 - accuracy: 0.9476 - val_loss: 0.1926 - val_auc: 0.9918 - val_precision: 0.9396 - val_recall: 0.9289 - val_precision_at_recall: 0.9932 - val_true_negatives: 94266.0000 - val_false_positives: 1914.0000 - val_specificity_at_sensitivity: 0.9988 - val_accuracy: 0.9342
# Epoch 22/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.1508 - auc: 0.9948 - precision: 0.9494 - recall: 0.9443 - precision_at_recall: 0.9976 - true_negatives: 94568.0000 - false_positives: 1612.0000 - specificity_at_sensitivity: 0.9996 - accuracy: 0.9467
# Epoch 22: accuracy did not improve from 0.94763
# 1002/1002 [==============================] - 138s 138ms/step - loss: 0.1508 - auc: 0.9948 - precision: 0.9494 - recall: 0.9443 - precision_at_recall: 0.9976 - true_negatives: 94568.0000 - false_positives: 1612.0000 - specificity_at_sensitivity: 0.9996 - accuracy: 0.9467 - val_loss: 0.1060 - val_auc: 0.9979 - val_precision: 0.9674 - val_recall: 0.9613 - val_precision_at_recall: 0.9994 - val_true_negatives: 95141.0000 - val_false_positives: 1039.0000 - val_specificity_at_sensitivity: 0.9999 - val_accuracy: 0.9643
# Epoch 23/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.1405 - auc: 0.9956 - precision: 0.9550 - recall: 0.9489 - precision_at_recall: 0.9984 - true_negatives: 94746.0000 - false_positives: 1434.0000 - specificity_at_sensitivity: 0.9997 - accuracy: 0.9514
# Epoch 23: accuracy improved from 0.94763 to 0.95143, saving model to classify_model4.h5
# 1002/1002 [==============================] - 140s 140ms/step - loss: 0.1405 - auc: 0.9956 - precision: 0.9550 - recall: 0.9489 - precision_at_recall: 0.9984 - true_negatives: 94746.0000 - false_positives: 1434.0000 - specificity_at_sensitivity: 0.9997 - accuracy: 0.9514 - val_loss: 0.1693 - val_auc: 0.9941 - val_precision: 0.9393 - val_recall: 0.9343 - val_precision_at_recall: 0.9972 - val_true_negatives: 94243.0000 - val_false_positives: 1937.0000 - val_specificity_at_sensitivity: 0.9995 - val_accuracy: 0.9369
# Epoch 24/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.1393 - auc: 0.9954 - precision: 0.9543 - recall: 0.9490 - precision_at_recall: 0.9979 - true_negatives: 94724.0000 - false_positives: 1456.0000 - specificity_at_sensitivity: 0.9996 - accuracy: 0.9519
# Epoch 24: accuracy improved from 0.95143 to 0.95193, saving model to classify_model4.h5
# 1002/1002 [==============================] - 140s 140ms/step - loss: 0.1393 - auc: 0.9954 - precision: 0.9543 - recall: 0.9490 - precision_at_recall: 0.9979 - true_negatives: 94724.0000 - false_positives: 1456.0000 - specificity_at_sensitivity: 0.9996 - accuracy: 0.9519 - val_loss: 0.2236 - val_auc: 0.9893 - val_precision: 0.9267 - val_recall: 0.9196 - val_precision_at_recall: 0.9929 - val_true_negatives: 93848.0000 - val_false_positives: 2332.0000 - val_specificity_at_sensitivity: 0.9987 - val_accuracy: 0.9233
# Epoch 25/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.1364 - auc: 0.9959 - precision: 0.9544 - recall: 0.9504 - precision_at_recall: 0.9982 - true_negatives: 94724.0000 - false_positives: 1456.0000 - specificity_at_sensitivity: 0.9997 - accuracy: 0.9526
# Epoch 25: accuracy improved from 0.95193 to 0.95256, saving model to classify_model4.h5
# 1002/1002 [==============================] - 165s 164ms/step - loss: 0.1364 - auc: 0.9959 - precision: 0.9544 - recall: 0.9504 - precision_at_recall: 0.9982 - true_negatives: 94724.0000 - false_positives: 1456.0000 - specificity_at_sensitivity: 0.9997 - accuracy: 0.9526 - val_loss: 0.2111 - val_auc: 0.9908 - val_precision: 0.9268 - val_recall: 0.9207 - val_precision_at_recall: 0.9960 - val_true_negatives: 93847.0000 - val_false_positives: 2333.0000 - val_specificity_at_sensitivity: 0.9993 - val_accuracy: 0.9237
# Epoch 26/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.1230 - auc: 0.9963 - precision: 0.9591 - recall: 0.9539 - precision_at_recall: 0.9981 - true_negatives: 94875.0000 - false_positives: 1305.0000 - specificity_at_sensitivity: 0.9996 - accuracy: 0.9566
# Epoch 26: accuracy improved from 0.95256 to 0.95658, saving model to classify_model4.h5
# 1002/1002 [==============================] - 139s 138ms/step - loss: 0.1230 - auc: 0.9963 - precision: 0.9591 - recall: 0.9539 - precision_at_recall: 0.9981 - true_negatives: 94875.0000 - false_positives: 1305.0000 - specificity_at_sensitivity: 0.9996 - accuracy: 0.9566 - val_loss: 0.1950 - val_auc: 0.9919 - val_precision: 0.9378 - val_recall: 0.9292 - val_precision_at_recall: 0.9969 - val_true_negatives: 94203.0000 - val_false_positives: 1977.0000 - val_specificity_at_sensitivity: 0.9994 - val_accuracy: 0.9333
# Epoch 27/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.1265 - auc: 0.9963 - precision: 0.9582 - recall: 0.9537 - precision_at_recall: 0.9984 - true_negatives: 94846.0000 - false_positives: 1334.0000 - specificity_at_sensitivity: 0.9997 - accuracy: 0.9558
# Epoch 27: accuracy did not improve from 0.95658
# 1002/1002 [==============================] - 138s 138ms/step - loss: 0.1265 - auc: 0.9963 - precision: 0.9582 - recall: 0.9537 - precision_at_recall: 0.9984 - true_negatives: 94846.0000 - false_positives: 1334.0000 - specificity_at_sensitivity: 0.9997 - accuracy: 0.9558 - val_loss: 0.1134 - val_auc: 0.9972 - val_precision: 0.9630 - val_recall: 0.9588 - val_precision_at_recall: 0.9992 - val_true_negatives: 94998.0000 - val_false_positives: 1182.0000 - val_specificity_at_sensitivity: 0.9999 - val_accuracy: 0.9615
# Epoch 28/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.1194 - auc: 0.9967 - precision: 0.9602 - recall: 0.9559 - precision_at_recall: 0.9986 - true_negatives: 94909.0000 - false_positives: 1271.0000 - specificity_at_sensitivity: 0.9997 - accuracy: 0.9579
# Epoch 28: accuracy improved from 0.95658 to 0.95792, saving model to classify_model4.h5
# 1002/1002 [==============================] - 139s 139ms/step - loss: 0.1194 - auc: 0.9967 - precision: 0.9602 - recall: 0.9559 - precision_at_recall: 0.9986 - true_negatives: 94909.0000 - false_positives: 1271.0000 - specificity_at_sensitivity: 0.9997 - accuracy: 0.9579 - val_loss: 0.0879 - val_auc: 0.9980 - val_precision: 0.9698 - val_recall: 0.9676 - val_precision_at_recall: 0.9989 - val_true_negatives: 95215.0000 - val_false_positives: 965.0000 - val_specificity_at_sensitivity: 0.9997 - val_accuracy: 0.9685
# Epoch 29/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.1143 - auc: 0.9967 - precision: 0.9612 - recall: 0.9573 - precision_at_recall: 0.9980 - true_negatives: 94940.0000 - false_positives: 1240.0000 - specificity_at_sensitivity: 0.9996 - accuracy: 0.9591
# Epoch 29: accuracy improved from 0.95792 to 0.95908, saving model to classify_model4.h5
# 1002/1002 [==============================] - 140s 140ms/step - loss: 0.1143 - auc: 0.9967 - precision: 0.9612 - recall: 0.9573 - precision_at_recall: 0.9980 - true_negatives: 94940.0000 - false_positives: 1240.0000 - specificity_at_sensitivity: 0.9996 - accuracy: 0.9591 - val_loss: 0.0858 - val_auc: 0.9987 - val_precision: 0.9743 - val_recall: 0.9700 - val_precision_at_recall: 0.9998 - val_true_negatives: 95359.0000 - val_false_positives: 821.0000 - val_specificity_at_sensitivity: 1.0000 - val_accuracy: 0.9720
# Epoch 30/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.1098 - auc: 0.9971 - precision: 0.9631 - recall: 0.9594 - precision_at_recall: 0.9990 - true_negatives: 95002.0000 - false_positives: 1178.0000 - specificity_at_sensitivity: 0.9998 - accuracy: 0.9611
# Epoch 30: accuracy improved from 0.95908 to 0.96107, saving model to classify_model4.h5
# 1002/1002 [==============================] - 140s 139ms/step - loss: 0.1098 - auc: 0.9971 - precision: 0.9631 - recall: 0.9594 - precision_at_recall: 0.9990 - true_negatives: 95002.0000 - false_positives: 1178.0000 - specificity_at_sensitivity: 0.9998 - accuracy: 0.9611 - val_loss: 0.0576 - val_auc: 0.9993 - val_precision: 0.9822 - val_recall: 0.9808 - val_precision_at_recall: 0.9999 - val_true_negatives: 95610.0000 - val_false_positives: 570.0000 - val_specificity_at_sensitivity: 1.0000 - val_accuracy: 0.9813
# Epoch 31/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.1128 - auc: 0.9967 - precision: 0.9631 - recall: 0.9593 - precision_at_recall: 0.9981 - true_negatives: 95002.0000 - false_positives: 1178.0000 - specificity_at_sensitivity: 0.9996 - accuracy: 0.9614
# Epoch 31: accuracy improved from 0.96107 to 0.96138, saving model to classify_model4.h5
# 1002/1002 [==============================] - 139s 139ms/step - loss: 0.1128 - auc: 0.9967 - precision: 0.9631 - recall: 0.9593 - precision_at_recall: 0.9981 - true_negatives: 95002.0000 - false_positives: 1178.0000 - specificity_at_sensitivity: 0.9996 - accuracy: 0.9614 - val_loss: 0.1505 - val_auc: 0.9953 - val_precision: 0.9481 - val_recall: 0.9435 - val_precision_at_recall: 0.9987 - val_true_negatives: 94523.0000 - val_false_positives: 1657.0000 - val_specificity_at_sensitivity: 0.9998 - val_accuracy: 0.9453
# Epoch 32/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.1085 - auc: 0.9971 - precision: 0.9636 - recall: 0.9602 - precision_at_recall: 0.9985 - true_negatives: 95016.0000 - false_positives: 1164.0000 - specificity_at_sensitivity: 0.9997 - accuracy: 0.9619
# Epoch 32: accuracy improved from 0.96138 to 0.96195, saving model to classify_model4.h5
# 1002/1002 [==============================] - 140s 140ms/step - loss: 0.1085 - auc: 0.9971 - precision: 0.9636 - recall: 0.9602 - precision_at_recall: 0.9985 - true_negatives: 95016.0000 - false_positives: 1164.0000 - specificity_at_sensitivity: 0.9997 - accuracy: 0.9619 - val_loss: 0.1404 - val_auc: 0.9959 - val_precision: 0.9499 - val_recall: 0.9466 - val_precision_at_recall: 0.9989 - val_true_negatives: 94578.0000 - val_false_positives: 1602.0000 - val_specificity_at_sensitivity: 0.9998 - val_accuracy: 0.9481
# Epoch 33/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.1026 - auc: 0.9973 - precision: 0.9648 - recall: 0.9619 - precision_at_recall: 0.9987 - true_negatives: 95056.0000 - false_positives: 1124.0000 - specificity_at_sensitivity: 0.9997 - accuracy: 0.9636
# Epoch 33: accuracy improved from 0.96195 to 0.96357, saving model to classify_model4.h5
# 1002/1002 [==============================] - 140s 140ms/step - loss: 0.1026 - auc: 0.9973 - precision: 0.9648 - recall: 0.9619 - precision_at_recall: 0.9987 - true_negatives: 95056.0000 - false_positives: 1124.0000 - specificity_at_sensitivity: 0.9997 - accuracy: 0.9636 - val_loss: 0.0667 - val_auc: 0.9991 - val_precision: 0.9757 - val_recall: 0.9738 - val_precision_at_recall: 0.9998 - val_true_negatives: 95404.0000 - val_false_positives: 776.0000 - val_specificity_at_sensitivity: 0.9999 - val_accuracy: 0.9747
# Epoch 34/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.0988 - auc: 0.9975 - precision: 0.9662 - recall: 0.9633 - precision_at_recall: 0.9986 - true_negatives: 95098.0000 - false_positives: 1082.0000 - specificity_at_sensitivity: 0.9997 - accuracy: 0.9649
# Epoch 34: accuracy improved from 0.96357 to 0.96491, saving model to classify_model4.h5
# 1002/1002 [==============================] - 139s 139ms/step - loss: 0.0988 - auc: 0.9975 - precision: 0.9662 - recall: 0.9633 - precision_at_recall: 0.9986 - true_negatives: 95098.0000 - false_positives: 1082.0000 - specificity_at_sensitivity: 0.9997 - accuracy: 0.9649 - val_loss: 0.0539 - val_auc: 0.9992 - val_precision: 0.9827 - val_recall: 0.9811 - val_precision_at_recall: 0.9996 - val_true_negatives: 95625.0000 - val_false_positives: 555.0000 - val_specificity_at_sensitivity: 0.9999 - val_accuracy: 0.9819
# Epoch 35/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.1007 - auc: 0.9974 - precision: 0.9664 - recall: 0.9630 - precision_at_recall: 0.9988 - true_negatives: 95108.0000 - false_positives: 1072.0000 - specificity_at_sensitivity: 0.9997 - accuracy: 0.9648
# Epoch 35: accuracy did not improve from 0.96491
# 1002/1002 [==============================] - 139s 139ms/step - loss: 0.1007 - auc: 0.9974 - precision: 0.9664 - recall: 0.9630 - precision_at_recall: 0.9988 - true_negatives: 95108.0000 - false_positives: 1072.0000 - specificity_at_sensitivity: 0.9997 - accuracy: 0.9648 - val_loss: 0.0709 - val_auc: 0.9987 - val_precision: 0.9744 - val_recall: 0.9725 - val_precision_at_recall: 0.9995 - val_true_negatives: 95360.0000 - val_false_positives: 820.0000 - val_specificity_at_sensitivity: 0.9999 - val_accuracy: 0.9734
# Epoch 36/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.0954 - auc: 0.9978 - precision: 0.9674 - recall: 0.9645 - precision_at_recall: 0.9992 - true_negatives: 95139.0000 - false_positives: 1041.0000 - specificity_at_sensitivity: 0.9998 - accuracy: 0.9656
# Epoch 36: accuracy improved from 0.96491 to 0.96563, saving model to classify_model4.h5
# 1002/1002 [==============================] - 140s 140ms/step - loss: 0.0954 - auc: 0.9978 - precision: 0.9674 - recall: 0.9645 - precision_at_recall: 0.9992 - true_negatives: 95139.0000 - false_positives: 1041.0000 - specificity_at_sensitivity: 0.9998 - accuracy: 0.9656 - val_loss: 0.0726 - val_auc: 0.9988 - val_precision: 0.9745 - val_recall: 0.9725 - val_precision_at_recall: 0.9996 - val_true_negatives: 95365.0000 - val_false_positives: 815.0000 - val_specificity_at_sensitivity: 0.9999 - val_accuracy: 0.9734
# Epoch 37/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.0881 - auc: 0.9979 - precision: 0.9715 - recall: 0.9688 - precision_at_recall: 0.9988 - true_negatives: 95268.0000 - false_positives: 912.0000 - specificity_at_sensitivity: 0.9997 - accuracy: 0.9700
# Epoch 37: accuracy improved from 0.96563 to 0.96996, saving model to classify_model4.h5
# 1002/1002 [==============================] - 139s 139ms/step - loss: 0.0881 - auc: 0.9979 - precision: 0.9715 - recall: 0.9688 - precision_at_recall: 0.9988 - true_negatives: 95268.0000 - false_positives: 912.0000 - specificity_at_sensitivity: 0.9997 - accuracy: 0.9700 - val_loss: 0.0736 - val_auc: 0.9987 - val_precision: 0.9726 - val_recall: 0.9710 - val_precision_at_recall: 0.9993 - val_true_negatives: 95304.0000 - val_false_positives: 876.0000 - val_specificity_at_sensitivity: 0.9998 - val_accuracy: 0.9717
# Epoch 38/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.0918 - auc: 0.9979 - precision: 0.9692 - recall: 0.9667 - precision_at_recall: 0.9991 - true_negatives: 95196.0000 - false_positives: 984.0000 - specificity_at_sensitivity: 0.9998 - accuracy: 0.9681
# Epoch 38: accuracy did not improve from 0.96996
# 1002/1002 [==============================] - 141s 140ms/step - loss: 0.0918 - auc: 0.9979 - precision: 0.9692 - recall: 0.9667 - precision_at_recall: 0.9991 - true_negatives: 95196.0000 - false_positives: 984.0000 - specificity_at_sensitivity: 0.9998 - accuracy: 0.9681 - val_loss: 0.0682 - val_auc: 0.9990 - val_precision: 0.9770 - val_recall: 0.9747 - val_precision_at_recall: 0.9998 - val_true_negatives: 95445.0000 - val_false_positives: 735.0000 - val_specificity_at_sensitivity: 0.9999 - val_accuracy: 0.9758
# Epoch 39/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.0939 - auc: 0.9977 - precision: 0.9685 - recall: 0.9655 - precision_at_recall: 0.9988 - true_negatives: 95173.0000 - false_positives: 1007.0000 - specificity_at_sensitivity: 0.9997 - accuracy: 0.9668
# Epoch 39: accuracy did not improve from 0.96996
# 1002/1002 [==============================] - 165s 165ms/step - loss: 0.0939 - auc: 0.9977 - precision: 0.9685 - recall: 0.9655 - precision_at_recall: 0.9988 - true_negatives: 95173.0000 - false_positives: 1007.0000 - specificity_at_sensitivity: 0.9997 - accuracy: 0.9668 - val_loss: 0.0481 - val_auc: 0.9995 - val_precision: 0.9842 - val_recall: 0.9822 - val_precision_at_recall: 0.9998 - val_true_negatives: 95675.0000 - val_false_positives: 505.0000 - val_specificity_at_sensitivity: 1.0000 - val_accuracy: 0.9832
# Epoch 40/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.0903 - auc: 0.9978 - precision: 0.9690 - recall: 0.9660 - precision_at_recall: 0.9985 - true_negatives: 95190.0000 - false_positives: 990.0000 - specificity_at_sensitivity: 0.9997 - accuracy: 0.9675
# Epoch 40: accuracy did not improve from 0.96996
# 1002/1002 [==============================] - 140s 140ms/step - loss: 0.0903 - auc: 0.9978 - precision: 0.9690 - recall: 0.9660 - precision_at_recall: 0.9985 - true_negatives: 95190.0000 - false_positives: 990.0000 - specificity_at_sensitivity: 0.9997 - accuracy: 0.9675 - val_loss: 0.0846 - val_auc: 0.9982 - val_precision: 0.9707 - val_recall: 0.9685 - val_precision_at_recall: 0.9991 - val_true_negatives: 95243.0000 - val_false_positives: 937.0000 - val_specificity_at_sensitivity: 0.9998 - val_accuracy: 0.9695
# Epoch 41/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.0846 - auc: 0.9981 - precision: 0.9715 - recall: 0.9689 - precision_at_recall: 0.9990 - true_negatives: 95269.0000 - false_positives: 911.0000 - specificity_at_sensitivity: 0.9998 - accuracy: 0.9701
# Epoch 41: accuracy improved from 0.96996 to 0.97006, saving model to classify_model4.h5
# 1002/1002 [==============================] - 140s 140ms/step - loss: 0.0846 - auc: 0.9981 - precision: 0.9715 - recall: 0.9689 - precision_at_recall: 0.9990 - true_negatives: 95269.0000 - false_positives: 911.0000 - specificity_at_sensitivity: 0.9998 - accuracy: 0.9701 - val_loss: 0.0892 - val_auc: 0.9981 - val_precision: 0.9717 - val_recall: 0.9679 - val_precision_at_recall: 0.9993 - val_true_negatives: 95275.0000 - val_false_positives: 905.0000 - val_specificity_at_sensitivity: 0.9998 - val_accuracy: 0.9697
# Epoch 42/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.0845 - auc: 0.9981 - precision: 0.9706 - recall: 0.9684 - precision_at_recall: 0.9990 - true_negatives: 95239.0000 - false_positives: 941.0000 - specificity_at_sensitivity: 0.9998 - accuracy: 0.9693
# Epoch 42: accuracy did not improve from 0.97006
# 1002/1002 [==============================] - 140s 139ms/step - loss: 0.0845 - auc: 0.9981 - precision: 0.9706 - recall: 0.9684 - precision_at_recall: 0.9990 - true_negatives: 95239.0000 - false_positives: 941.0000 - specificity_at_sensitivity: 0.9998 - accuracy: 0.9693 - val_loss: 0.0698 - val_auc: 0.9988 - val_precision: 0.9777 - val_recall: 0.9750 - val_precision_at_recall: 0.9994 - val_true_negatives: 95467.0000 - val_false_positives: 713.0000 - val_specificity_at_sensitivity: 0.9999 - val_accuracy: 0.9761
# Epoch 43/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.0879 - auc: 0.9979 - precision: 0.9704 - recall: 0.9679 - precision_at_recall: 0.9988 - true_negatives: 95234.0000 - false_positives: 946.0000 - specificity_at_sensitivity: 0.9997 - accuracy: 0.9693
# Epoch 43: accuracy did not improve from 0.97006
# 1002/1002 [==============================] - 140s 140ms/step - loss: 0.0879 - auc: 0.9979 - precision: 0.9704 - recall: 0.9679 - precision_at_recall: 0.9988 - true_negatives: 95234.0000 - false_positives: 946.0000 - specificity_at_sensitivity: 0.9997 - accuracy: 0.9693 - val_loss: 0.0448 - val_auc: 0.9995 - val_precision: 0.9873 - val_recall: 0.9857 - val_precision_at_recall: 0.9998 - val_true_negatives: 95773.0000 - val_false_positives: 407.0000 - val_specificity_at_sensitivity: 1.0000 - val_accuracy: 0.9865
# Epoch 44/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.0831 - auc: 0.9981 - precision: 0.9725 - recall: 0.9703 - precision_at_recall: 0.9989 - true_negatives: 95299.0000 - false_positives: 881.0000 - specificity_at_sensitivity: 0.9998 - accuracy: 0.9714
# Epoch 44: accuracy improved from 0.97006 to 0.97137, saving model to classify_model4.h5
# 1002/1002 [==============================] - 140s 139ms/step - loss: 0.0831 - auc: 0.9981 - precision: 0.9725 - recall: 0.9703 - precision_at_recall: 0.9989 - true_negatives: 95299.0000 - false_positives: 881.0000 - specificity_at_sensitivity: 0.9998 - accuracy: 0.9714 - val_loss: 0.0342 - val_auc: 0.9998 - val_precision: 0.9893 - val_recall: 0.9882 - val_precision_at_recall: 0.9999 - val_true_negatives: 95837.0000 - val_false_positives: 343.0000 - val_specificity_at_sensitivity: 1.0000 - val_accuracy: 0.9887
# Epoch 45/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.0821 - auc: 0.9982 - precision: 0.9714 - recall: 0.9688 - precision_at_recall: 0.9991 - true_negatives: 95264.0000 - false_positives: 916.0000 - specificity_at_sensitivity: 0.9998 - accuracy: 0.9699
# Epoch 45: accuracy did not improve from 0.97137
# 1002/1002 [==============================] - 141s 141ms/step - loss: 0.0821 - auc: 0.9982 - precision: 0.9714 - recall: 0.9688 - precision_at_recall: 0.9991 - true_negatives: 95264.0000 - false_positives: 916.0000 - specificity_at_sensitivity: 0.9998 - accuracy: 0.9699 - val_loss: 0.0716 - val_auc: 0.9988 - val_precision: 0.9724 - val_recall: 0.9715 - val_precision_at_recall: 0.9995 - val_true_negatives: 95296.0000 - val_false_positives: 884.0000 - val_specificity_at_sensitivity: 0.9999 - val_accuracy: 0.9720
# Epoch 46/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.0797 - auc: 0.9982 - precision: 0.9726 - recall: 0.9706 - precision_at_recall: 0.9989 - true_negatives: 95304.0000 - false_positives: 876.0000 - specificity_at_sensitivity: 0.9997 - accuracy: 0.9717
# Epoch 46: accuracy improved from 0.97137 to 0.97168, saving model to classify_model4.h5
# 1002/1002 [==============================] - 141s 140ms/step - loss: 0.0797 - auc: 0.9982 - precision: 0.9726 - recall: 0.9706 - precision_at_recall: 0.9989 - true_negatives: 95304.0000 - false_positives: 876.0000 - specificity_at_sensitivity: 0.9997 - accuracy: 0.9717 - val_loss: 0.1532 - val_auc: 0.9943 - val_precision: 0.9505 - val_recall: 0.9457 - val_precision_at_recall: 0.9959 - val_true_negatives: 94601.0000 - val_false_positives: 1579.0000 - val_specificity_at_sensitivity: 0.9991 - val_accuracy: 0.9481
# Epoch 47/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.0786 - auc: 0.9984 - precision: 0.9731 - recall: 0.9713 - precision_at_recall: 0.9992 - true_negatives: 95320.0000 - false_positives: 860.0000 - specificity_at_sensitivity: 0.9998 - accuracy: 0.9723
# Epoch 47: accuracy improved from 0.97168 to 0.97233, saving model to classify_model4.h5
# 1002/1002 [==============================] - 140s 140ms/step - loss: 0.0786 - auc: 0.9984 - precision: 0.9731 - recall: 0.9713 - precision_at_recall: 0.9992 - true_negatives: 95320.0000 - false_positives: 860.0000 - specificity_at_sensitivity: 0.9998 - accuracy: 0.9723 - val_loss: 0.0398 - val_auc: 0.9996 - val_precision: 0.9856 - val_recall: 0.9851 - val_precision_at_recall: 0.9998 - val_true_negatives: 95718.0000 - val_false_positives: 462.0000 - val_specificity_at_sensitivity: 1.0000 - val_accuracy: 0.9854
# Epoch 48/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.0747 - auc: 0.9982 - precision: 0.9747 - recall: 0.9729 - precision_at_recall: 0.9986 - true_negatives: 95370.0000 - false_positives: 810.0000 - specificity_at_sensitivity: 0.9997 - accuracy: 0.9738
# Epoch 48: accuracy improved from 0.97233 to 0.97377, saving model to classify_model4.h5
# 1002/1002 [==============================] - 142s 141ms/step - loss: 0.0747 - auc: 0.9982 - precision: 0.9747 - recall: 0.9729 - precision_at_recall: 0.9986 - true_negatives: 95370.0000 - false_positives: 810.0000 - specificity_at_sensitivity: 0.9997 - accuracy: 0.9738 - val_loss: 0.0350 - val_auc: 0.9997 - val_precision: 0.9877 - val_recall: 0.9871 - val_precision_at_recall: 0.9999 - val_true_negatives: 95785.0000 - val_false_positives: 395.0000 - val_specificity_at_sensitivity: 1.0000 - val_accuracy: 0.9873
# Epoch 49/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.0735 - auc: 0.9984 - precision: 0.9750 - recall: 0.9731 - precision_at_recall: 0.9990 - true_negatives: 95379.0000 - false_positives: 801.0000 - specificity_at_sensitivity: 0.9998 - accuracy: 0.9741
# Epoch 49: accuracy improved from 0.97377 to 0.97414, saving model to classify_model4.h5
# 1002/1002 [==============================] - 141s 140ms/step - loss: 0.0735 - auc: 0.9984 - precision: 0.9750 - recall: 0.9731 - precision_at_recall: 0.9990 - true_negatives: 95379.0000 - false_positives: 801.0000 - specificity_at_sensitivity: 0.9998 - accuracy: 0.9741 - val_loss: 0.1248 - val_auc: 0.9962 - val_precision: 0.9607 - val_recall: 0.9582 - val_precision_at_recall: 0.9980 - val_true_negatives: 94924.0000 - val_false_positives: 1256.0000 - val_specificity_at_sensitivity: 0.9995 - val_accuracy: 0.9593
# Epoch 50/50
# 1002/1002 [==============================] - ETA: 0s - loss: 0.0747 - auc: 0.9983 - precision: 0.9744 - recall: 0.9727 - precision_at_recall: 0.9987 - true_negatives: 95360.0000 - false_positives: 820.0000 - specificity_at_sensitivity: 0.9997 - accuracy: 0.9737
# Epoch 50: accuracy did not improve from 0.97414
# 1002/1002 [==============================] - 141s 141ms/step - loss: 0.0747 - auc: 0.9983 - precision: 0.9744 - recall: 0.9727 - precision_at_recall: 0.9987 - true_negatives: 95360.0000 - false_positives: 820.0000 - specificity_at_sensitivity: 0.9997 - accuracy: 0.9737 - val_loss: 0.0665 - val_auc: 0.9988 - val_precision: 0.9780 - val_recall: 0.9762 - val_precision_at_recall: 0.9995 - val_true_negatives: 95475.0000 - val_false_positives: 705.0000 - val_specificity_at_sensitivity: 0.9999 - val_accuracy: 0.9771

# %%
plt.plot(history_5.history["loss"], label="train_loss")
plt.plot(history_5.history["val_loss"], label="val_loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Train and Validation Losses Over Epochs", fontsize=14)
plt.legend()
plt.grid()
plt.show()

# %%
plt.plot(history_5.history["accuracy"], label="accuracy")
plt.plot(history_5.history["val_accuracy"], label="val_accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Train and Validation Accuracy Over Epochs", fontsize=14)
plt.legend()
plt.grid()
plt.show()

# %%
test_score = custom5.evaluate_generator(val_set, batch_size)
print("[INFO] accuracy: {:.2f}%".format(test_score[1] * 100))
print("[INFO] Loss: ",test_score[0])

# %%
# Magic function that renders the figure in a jupyter notebook
# instead of displaying a figure object
# %matplotlib inline
y_true = train_set
classesIndexes, classesFrequency = np.unique(y_true, return_counts=True)
labels = val_set

# Setting default size of the plot
plt.rcParams['figure.figsize'] = (10.0, 7.0)


# Plotting histogram of 5 classes with their number of samples
# Defining a figure object 
figure = plt.figure()


# Plotting Bar chart
plt.bar(classesIndexes, classesFrequency, align='center', alpha=0.6)


# Giving name to Y axis
plt.ylabel('Class frequency', fontsize=16)


# Giving names to every Bar along X axis
plt.xticks(classesIndexes, labels, fontsize=16)


# Giving name to the plot
plt.title('Histogram', fontsize=20)


# Saving the plot
figure.savefig('histogram.png', transparent=True, dpi=500)


# Showing the plot
plt.show()

# %%
# Confusion Matrix
from sklearn.metrics import confusion_matrix
confusion_matrix(y_true, y_pred)

# %%
t_n= tf.keras.metrics.TrueNegatives()
f_p= tf.keras.metrics.FalsePositives()
#t_P = tf.keras.metrics.TruePositives()
#f_n = tf.keras.metrics.FalseNegatives()

# %%
import sklearn

# %%
from sklearn.metrics import confusion_matrix
sklearn.metrics.confusion_matrix(t_n, f_p, labels=None, sample_weight=None, normalize=None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-f150d2df48a9> in <module>
#       1 from sklearn.metrics import confusion_matrix
# ----> 2 sklearn.metrics.confusion_matrix(t_n, f_p, labels=None, sample_weight=None, normalize=None)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     305     (0, 2, 1, 1)
#     306     """
# --> 307     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     308     if y_type not in ("binary", "multiclass"):
#     309         raise ValueError("%s is not supported" % y_type)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      82     y_pred : array or indicator matrix
#      83     """
# ---> 84     check_consistent_length(y_true, y_pred)
#      85     type_true = type_of_target(y_true)
#      86     type_pred = type_of_target(y_pred)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     327     """
#     328
# --> 329     lengths = [_num_samples(X) for X in arrays if X is not None]
#     330     uniques = np.unique(lengths)
#     331     if len(uniques) > 1:
#
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py in <listcomp>(.0)
#     327     """
#     328
# --> 329     lengths = [_num_samples(X) for X in arrays if X is not None]
#     330     uniques = np.unique(lengths)
#     331     if len(uniques) > 1:
#
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py in _num_samples(x)
#     263             x = np.asarray(x)
#     264         else:
# --> 265             raise TypeError(message)
#     266
#     267     if hasattr(x, "shape") and x.shape is not None:
#
# TypeError: Expected sequence or array-like, got <class 'keras.metrics.metrics.TrueNegatives'>

# %%
y_pred = custom5.predict(val_set)
# Out:
# 1002/1002 [==============================] - 66s 66ms/step

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(train_set, y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-5e560f378331> in <module>
#       1 from sklearn.metrics import confusion_matrix
# ----> 2 confusion_matrix(train_set, y_pred)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     305     (0, 2, 1, 1)
#     306     """
# --> 307     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     308     if y_type not in ("binary", "multiclass"):
#     309         raise ValueError("%s is not supported" % y_type)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      82     y_pred : array or indicator matrix
#      83     """
# ---> 84     check_consistent_length(y_true, y_pred)
#      85     type_true = type_of_target(y_true)
#      86     type_pred = type_of_target(y_pred)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     330     uniques = np.unique(lengths)
#     331     if len(uniques) > 1:
# --> 332         raise ValueError(
#     333             "Found input variables with inconsistent numbers of samples: %r"
#     334             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [1002, 32060]
